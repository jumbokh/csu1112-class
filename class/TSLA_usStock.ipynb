# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/csu1112-class/blob/main/class/TSLA_usStock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf

# %%
yf.pdr_override()

# %%
doge = pdr.get_data_yahoo("DOGE-USD")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(doge)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415    6259550
# 2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163    4246520
# 2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201    2231080
# 2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038    3288960
# 2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211    2481270
# ...              ...       ...       ...       ...        ...        ...
# 2023-03-13  0.071000  0.073726  0.068514  0.073041   0.073041  537268873
# 2023-03-14  0.073036  0.077640  0.071777  0.074787   0.074787  652033915
# 2023-03-15  0.074805  0.076058  0.068141  0.069866   0.069866  528466415
# 2023-03-16  0.069878  0.073477  0.069254  0.072718   0.072718  326147102
# 2023-03-18  0.076516  0.078694  0.076153  0.077947   0.077947  548247744
#
# [1955 rows x 6 columns]

# %%
tsla = pdr.get_data_yahoo("TSLA")
print(tsla)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-03-13  167.460007  177.350006  163.910004  174.479996  174.479996
# 2023-03-14  177.309998  183.800003  177.139999  183.259995  183.259995
# 2023-03-15  180.800003  182.339996  176.029999  180.449997  180.449997
# 2023-03-16  180.369995  185.809998  178.839996  184.130005  184.130005
# 2023-03-17  184.520004  186.220001  177.330002  180.130005  180.130005
#
#                Volume
# Date
# ...

# %%
tsla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
tsla.head().to_json(orient="values")
# Out:
# '[[1.2666670084,1.6666669846,1.1693329811,1.5926669836,1.5926669836,281494500],[1.7193330526,2.0280001163,1.5533330441,1.5886670351,1.5886670351,257806500],[1.6666669846,1.7280000448,1.3513330221,1.4639999866,1.4639999866,123282000],[1.5333329439,1.5399999619,1.2473330498,1.2799999714,1.2799999714,77097000],[1.3333330154,1.3333330154,1.0553330183,1.074000001,1.074000001,103003500]]'

# %%
tsla['Date'] = tsla.index

# %%
tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3202 entries, 2010-06-29 to 2023-03-17
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3202 non-null   float64
#  1   High       3202 non-null   float64
#  2   Low        3202 non-null   float64
#  3   Close      3202 non-null   float64
#  4   Adj Close  3202 non-null   float64
#  5   Volume     3202 non-null   int64
#  6   Date       3202 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 200.1 KB

# %%
tsla['Date'] = tsla['Date'].dt.strftime('%Y/%m/%d')

# %%
tsla[['Date','Open','Close','Low','High']].head().to_json(orient="values")
# Out:
# '[["2010\\/06\\/29",1.2666670084,1.5926669836,1.1693329811,1.6666669846],["2010\\/06\\/30",1.7193330526,1.5886670351,1.5533330441,2.0280001163],["2010\\/07\\/01",1.6666669846,1.4639999866,1.3513330221,1.7280000448],["2010\\/07\\/02",1.5333329439,1.2799999714,1.2473330498,1.5399999619],["2010\\/07\\/06",1.3333330154,1.074000001,1.0553330183,1.3333330154]]'

# %%
tsla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#                   Date
# Date
# 2010-06-29  2010/06/29
# 2010-06-30  2010/06/30
# 2010-07-01  2010/07/01
# 2010-07-02  2010/07/02
# 2010-07-06  2010/07/06

# %%
tsla[['Date','Open','Close','Low','High']].head()
# Out:
#                   Date      Open     Close       Low      High
# Date
# 2010-06-29  2010/06/29  1.266667  1.592667  1.169333  1.666667
# 2010-06-30  2010/06/30  1.719333  1.588667  1.553333  2.028000
# 2010-07-01  2010/07/01  1.666667  1.464000  1.351333  1.728000
# 2010-07-02  2010/07/02  1.533333  1.280000  1.247333  1.540000
# 2010-07-06  2010/07/06  1.333333  1.074000  1.055333  1.333333

# %%
tsla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-03-13  167.460007  177.350006  163.910004  174.479996  174.479996
# 2023-03-14  177.309998  183.800003  177.139999  183.259995  183.259995
# 2023-03-15  180.800003  182.339996  176.029999  180.449997  180.449997
# 2023-03-16  180.369995  185.809998  178.839996  184.130005  184.130005
# 2023-03-17  184.520004  186.220001  177.330002  180.130005  180.130005
#
#                Volume        Date
# Date
# 2023-03-13  167790300  2023/03/13
# 2023-03-14  143717900  2023/03/14
# 2023-03-15  145995600  2023/03/15
# 2023-03-16  121374500  2023/03/16
# 2023-03-17  132936600  2023/03/17

# %% [markdown]
# ## 練習一
#
# 請計算TSLA股價從上市第一天到現在漲了幾倍？

# %%
tsla['Close'][-1]/tsla['Close'][0]
# Out:
# 113.09960383253049

# %% [markdown]
# ## 練習二
#
# 請計算TSLA從2010年以來，每一年的投資報酬率。

# %%
tsla['2010']['Close'][-1]/tsla['2010']['Close'][0]
# Out:
# <ipython-input-19-0b1f0d1b1659>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   tsla['2010']['Close'][-1]/tsla['2010']['Close'][0]
# 1.1146919382326346

# %%
x = 1.0

for i in range(13):
  year = str(2010 + i)
  ret = tsla[year]['Close'][-1]/tsla[year]['Close'][0]
  print(year, "==>", ret)
  x *= ret

x
# Out:
# 2010 ==> 1.1146919382326346
# 2011 ==> 1.0728773440103994
# 2012 ==> 1.2061965396956114
# 2013 ==> 4.2542431147774264
# 2014 ==> 1.4817454450219967
# 2015 ==> 1.0943869435813898
# 2016 ==> 0.9564925633701342
# 2017 ==> 1.4348587551998524
# 2018 ==> 1.038280294369463
# 2019 ==> 1.3489293766859665
# 2020 ==> 8.200506467423963
# 2021 ==> 1.4481001179959765
# 2022 ==> 0.3080064689288968
# <ipython-input-21-c672afbdbcf9>:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ret = tsla[year]['Close'][-1]/tsla[year]['Close'][0]
# 69.96542843322906

# %% [markdown]
# ## 練習三
#
# 請繪製TSLA從2020年至今的收盤價曲線。

# %%
tsla['2020':]['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 練習四
#
# 請繪製TSLA從2021年至今的成交量長條圖。

# %%
tsla['2021']['Volume'].plot(kind='bar')
# Out:
# <ipython-input-23-3968bec8c655>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   tsla['2021']['Volume'].plot(kind='bar')
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 練習五
#
# 請繪製TSLA從2021年至今的K線圖。
#
# https://github.com/matplotlib/mplfinance

# %%
# !pip install mplfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 2.6 MB/s eta 0:00:00
# ...

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
import mplfinance as mpf

# %%
mpf.plot(tsla['2021-06':],type='candle')
